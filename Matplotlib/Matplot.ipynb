# %%
# Importing necessary libraries
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Bringing in the dataset
df = pd.read_csv("C:\DiabetesData\Diabetes_Dataset.csv")
df
# Out:
#       ID  No_Pation Gender  AGE  Urea   Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0    177      45364      F   20   4.6   70    9.6   4.1  1.8  1.0  2.3   0.8
# 1    147      45365      F   25  10.0   35    4.0   4.3  3.5  0.8  1.3   0.8
# 2    735      34221      M   26   4.5   62    4.9   3.7  1.4  1.1  2.1   0.6
# 3    129      45416      M   26   7.5   79    8.8   3.5  2.0  2.0  0.9   0.5
# 4     67      34222      F   28   4.1   73    4.9   5.3  3.2  0.8  0.8   0.9
# ..   ...        ...    ...  ...   ...  ...    ...   ...  ...  ...  ...   ...
# 995  165      45412      F   77   5.0  106    5.4   3.9  2.1  1.2  4.2   1.1
# 996  186     454316      M   77   5.0  106    5.4   0.0  2.8  0.8  1.8   0.7
# 997  339       5980      M   77   6.2   99    7.2   3.2  1.1  0.8  2.0   0.5
# 998  389      24101      M   77   6.2   99    7.2   3.2  1.1  0.8  2.0   0.5
# 999  171      42329      F   79   5.2   54    9.2   6.4  3.0  1.1  4.1   1.3
#
#       BMI CLASS
# 0    30.0     Y
# ...

# %%
df.head()
# Out:
#     ID  No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0  177      45364      F   20   4.6  70    9.6   4.1  1.8  1.0  2.3   0.8
# 1  147      45365      F   25  10.0  35    4.0   4.3  3.5  0.8  1.3   0.8
# 2  735      34221      M   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6
# 3  129      45416      M   26   7.5  79    8.8   3.5  2.0  2.0  0.9   0.5
# 4   67      34222      F   28   4.1  73    4.9   5.3  3.2  0.8  0.8   0.9
#
#     BMI CLASS
# 0  30.0     Y
# 1  22.0     N
# 2  23.0     N
# 3  28.0     Y
# 4  24.0     Y

# %%
df.tail()
# Out:
#       ID  No_Pation Gender  AGE  Urea   Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 995  165      45412      F   77   5.0  106    5.4   3.9  2.1  1.2  4.2   1.1
# 996  186     454316      M   77   5.0  106    5.4   0.0  2.8  0.8  1.8   0.7
# 997  339       5980      M   77   6.2   99    7.2   3.2  1.1  0.8  2.0   0.5
# 998  389      24101      M   77   6.2   99    7.2   3.2  1.1  0.8  2.0   0.5
# 999  171      42329      F   79   5.2   54    9.2   6.4  3.0  1.1  4.1   1.3
#
#       BMI CLASS
# 995  24.0     N
# 996  19.0     N
# 997  29.0     Y
# 998  29.0     Y
# 999  30.0     Y

# %%
# Making all columns into their own individual lists 
Id = list(df["ID"])
PationNo = list(df["No_Pation"])
gen = list(df["Gender"])
age = list(df["AGE"])
urea = list(df["Urea"])
cr = list(df["Cr"])
hba1c = list(df["HbA1c"])
chole = list(df["Chol"])
tg = list(df["TG"])
hdl = list(df["HDL"])
ldl = list(df["LDL"])
vldl = list(df["VLDL"])
bmi = list(df["BMI"])
clas = list(df["CLASS"])

# %% [markdown]
# Line-plots

# %%
fig, ax = plt.subplots()
ax.plot(bmi,urea)
ax.set_xlabel("Age")
ax.set_ylabel("Urea")
ax.set_title("Age vs Urea")
# Out:
# Text(0.5, 1.0, 'Age vs Urea')

# %%
fig = plt.figure()  # an empty figure with no Axes
fig, ax = plt.subplots()  # a figure with a single Axes
fig, axs = plt.subplots(2, 2)  # a figure with a 2x2 grid of Axes
# a figure with one axes on the left, and two on the right:
fig, axs = plt.subplot_mosaic([['left', 'right_top'],
                               ['left', 'right_bottom']])

# %%
b = np.matrix([[1, 2], [3, 4]])
b_asarray = np.asarray(b)

# %%
x = np.linspace(0, 2, 100)  # Sample data.

plt.figure(figsize=(5, 2.7), layout='constrained')
plt.plot(x, x, label='linear')  # Plot some data on the (implicit) axes.
plt.plot(x, x**2, label='quadratic')  # etc.
plt.plot(x, x**3, label='cubic')
plt.xlabel('x label')
plt.ylabel('y label')
plt.title("Simple Plot")
plt.legend()

# %%
def my_plotter(ax, data1, data2, param_dict):
    """
    A helper function to make a graph.
    """
    out = ax.plot(data1, data2, **param_dict)
    return out

# %%
fig, ax = plt.subplots(figsize=(7.5,5)) # 7.5 = Width, 5 = Height
ax.scatter(age, hba1c, s=50, facecolor='C0', edgecolor='k')
ax.set_xlabel("Age")
ax.set_ylabel("HbA1c")
ax.set_title("Age and HbA1c")
# Out:
# Text(0.5, 1.0, 'Age and HbA1c')

# %%
data1, data2, data3, data4 = np.random.randn(4, 100)  # make 4 random data sets
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(5, 2.7))
my_plotter(ax1, data1, data2, {'marker': 'x'})
my_plotter(ax2, data3, data4, {'marker': 'o'})

# %%
mu, sigma = 115, 15
x = mu + sigma * np.random.randn(10000)
fig, ax = plt.subplots(figsize=(10, 2.7), layout='constrained')
# the histogram of the data
n, bins, patches = ax.hist(x, 50, density=True, facecolor='C0', alpha=0.75)

ax.set_xlabel('Length [cm]')
ax.set_ylabel('Probability')
ax.set_title('Aardvark lengths\n (not really)')
ax.text(75, .025, r'$\mu=115,\ \sigma=15$')
ax.axis([55, 175, 0, 0.03])
ax.grid(True)

# %%
fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')
plt.hist(cr)
ax.set_xlabel("Age")
ax.set_ylabel("Urea")
ax.set_title("Age and Urea")
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(5, 2.7), layout='constrained')
xdata = np.arange(len(data1))  # make an ordinal for this
data = 10**data1
axs[0].plot(xdata, data)

axs[1].set_yscale('log')
axs[1].plot(xdata, data)

# %%
x,y = [],[]
for i in gen:
    if i == 'F':
        x.append(i)
    else: 
        y.append(i)

fig, ax = plt.subplots(figsize=(5, 3), layout='constrained')
categories = ['Female','Male']
bats = [len(x),len(y)]

ax.bar(categories, bats)
# Out:
# <BarContainer object of 2 artists>

# %%
X, Y = np.meshgrid(np.linspace(-3, 3, 128), np.linspace(-3, 3, 128))
Z = (1 - X/2 + X**5 + Y**3) * np.exp(-X**2 - Y**2)

fig, axs = plt.subplots(2, 2, layout='constrained')
pc = axs[0, 0].pcolormesh(X, Y, Z, vmin=-1, vmax=1, cmap='RdBu_r')
fig.colorbar(pc, ax=axs[0, 0])
axs[0, 0].set_title('pcolormesh()')

co = axs[0, 1].contourf(X, Y, Z, levels=np.linspace(-1.25, 1.25, 11))
fig.colorbar(co, ax=axs[0, 1])
axs[0, 1].set_title('contourf()')

pc = axs[1, 0].imshow(Z**2 * 100, cmap='plasma',
                          norm=mpl.colors.LogNorm(vmin=0.01, vmax=100))
fig.colorbar(pc, ax=axs[1, 0], extend='both')
axs[1, 0].set_title('imshow() with LogNorm()')

pc = axs[1, 1].scatter(data1, data2, c=data3, cmap='RdBu_r')
fig.colorbar(pc, ax=axs[1, 1], extend='both')
axs[1, 1].set_title('scatter()')
# Out:
# Text(0.5, 1.0, 'scatter()')

# %%
fig, ax = plt.subplots(figsize=(3, 4), layout='constrained')
ax.boxplot(hdl)
ax.set_title("HDL")
# Out:
# Text(0.5, 1.0, 'HDL')
